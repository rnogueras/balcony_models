# %%
import collections
import re
import string

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF

import spacy
import nltk
from nltk.stem import WordNetLemmatizer

from utils import (
    drop_spam_rows,
    remove_digits,
    remove_prefixed_words,
    contract_spaces,
    remove_word,
    remove_single_characters,
    remove_special_characters,
)
# Out:
# /home/robert/miniconda3/envs/balcony-models/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ### Load spaCy Spanish trained pipeline.

# %%
try:
    sp = spacy.load("es_core_news_sm")
except OSError:
    # !python3 -m spacy download es_core_news_sm
    sp = spacy.load("es_core_news_sm")

# %%
nltk.download("stopwords")
nltk.download("wordnet")
nltk.download("omw-1.4")
# Out:
# [nltk_data] Downloading package stopwords to /home/robert/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/robert/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/robert/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %% [markdown]
# ### Load texts

# %%
dataset_path = "data/balcones_2020.csv"
dataset = pd.read_csv(dataset_path)
texts = dataset["text"]

# %% [markdown]
# ### Remove spam

# %%
spam_texts = ["El Magazin del Balcón Segoviano", "Viva María Auxiliadora"]
texts = drop_spam_rows(text_series=texts, spam_messages=spam_texts)

# %% [markdown]
# ### Preprocessing

# %%
PUNCTUATION_MARKS = string.punctuation + "¿¡" + "..." + "…" + " "
STOP_WORDS = nltk.corpus.stopwords.words("spanish")
UNDESIRED_WORDS = [
    "balcón",
    "balcones",
    "balcon",
    "si",
    "haber",
    "ser",
    "quedateencasa",
    "yomequedoencasa",
    "parir"
]
UNDESIRED_PREFIXES = ["@", "#", "http", "jaj", "xd", "xD", "XD"]


def tokenize(text):
    return " ".join(
        [
            token.lemma_ for token in sp(text)
            if token.text not in PUNCTUATION_MARKS
            and token.text not in STOP_WORDS + UNDESIRED_WORDS
        ]
    )

def preprocess_text(text):

    text = text.lower()
    # Regex filters.
    for prefix in UNDESIRED_PREFIXES:
            text = remove_prefixed_words(prefix, text)
    text = remove_special_characters(text)
    text = remove_single_characters(text)
    text = remove_digits(text)
    text = contract_spaces(text)
    return tokenize(text)

# %%
texts_preprocessed = texts.apply(lambda x: preprocess_text(x))

# %% [markdown]
# ### TF-IDF Vectorizer

# %%
tf = TfidfVectorizer(
    stop_words=(STOP_WORDS),
    min_df=3,
    max_df=0.85,
    ngram_range=(1, 2)
)
X = tf.fit_transform(texts_preprocessed)

# %%
feature_names = tf.get_feature_names_out()
words = np.array(tf.get_feature_names_out())
matrix = pd.DataFrame(X.toarray(), columns = feature_names)

# %% [markdown]
# ### NMF

# %%
model = NMF(n_components=15, random_state=10)
nmf_output = model.fit_transform(X)

# %%
components_df = pd.DataFrame(model.components_, columns=feature_names)

# %%
components_df
# Out:
#        abajo   abascal     abeja   abierto   abrazar  abrazarno    abrazo  \
# 0   0.011728  0.000000  0.001336  0.000000  0.003365   0.000000  0.000000
# 1   0.000000  0.000000  0.000000  0.000000  0.000431   0.000000  0.000000
# 2   0.001088  0.000000  0.000000  0.000235  0.000000   0.000000  0.000000
# 3   0.036930  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 4   0.000000  0.000000  0.000000  0
# 7       0.006436  0.000000         0.000000
# 8       0.000000  0.000962         0.000237
# 9       0.000000  0.000000         0.000000
# 10      0.000000  0.002603         0.000159
# 11      0.001375  0.000440         0.000265
# 12      0.001591  0.004777         0.000004
# 13      0.000969  0.000000         0.000000
# 14      0.000000  0.000000         0.000000
#
# [15 rows x 6413 columns]

# %% [markdown]
# ### Topics

# %%
for topic in range(components_df.shape[0]):
    tmp = components_df.iloc[topic]
    print(f'For topic {topic} the words with the highest value are:')
    print(tmp.nlargest(10))
    print('\n')
# Out:
# For topic 0 the words with the highest value are:
# salir             4.504302
# salir aplaudir    0.691029
# poder salir       0.652369
# poder             0.614710
# ir salir          0.342918
# salir cantar      0.277432
# cantar            0.230656
# salir calle       0.206934
# hora salir        0.202030
# hora              0.194266
# Name: 0, dtype: float64
#
#
# For topic 1 the words with the highest value are:
# aplaudir              2.057521
# salir aplaudir        0.770545
# luego                 0.291644
# sanitario             0.238871
# sanidad               0.158732
# aplaudir sanitario    0.145544
# seguro                0.127300
# público               0.118316
# sanidad público       0.097566
# salgo                 0.093803
# Name: 1, dtype: float64
#
#
# For topic 2 the words with the highest value are:
# cantar             0.844968
# bella              0.714873
# bella ciao         0.714873
# ciao               0.713700
# cantar bella       0.703115
# italiano cantar    0.699438
# fascismo           0.698886
# italiano           0.692155
# año caída          0.684212
# ciao año           0.684212
# Name: 2, dtype: float64
#
#
# For topic 3 the words with the highest value are:
# tirar           2.671490
# ir tirar        0.163862
# querer tirar    0.146367
# poder tirar     0.124139
# querer          0.116307
# poder           0.090868
# cuarentena      0.078158
# dos             0.077651
# gana tirar      0.077262
# mirar tirar     0.071574
# Name: 3, dtype: float64
#
#
# For topic 4 the words with the highest value are:
# día               2.077672
# cada              0.548079
# cada día          0.435542
# buen              0.360785
# buen día          0.318132
# cuarentena        0.195511
# aplauso           0.187802
# vecino            0.167262
# menos             0.161808
# día cuarentena    0.147455
# Name: 4, dtype: float64
#
#
# For topic 5 the words with the highest value are:
# hacer          2.115050
# poder          0.210439
# poder hacer    0.152824
# cosa           0.138596
# cuarentena     0.104632
# mismo          0.102720
# saber          0.093782
# fiesta         0.092859
# hacer cosa     0.090074
# hacer salir    0.089133
# Name: 5, dtype: float64
#
#
# For topic 6 the words with the highest value are:
# poner           1.962478
# vecino          0.856223
# música          0.852113
# poner música    0.630562
# mañana          0.395742
# vecino poner    0.179954
# altavoz         0.157780
# himno           0.141651
# poner himno     0.135080
# ir poner        0.131434
# Name: 6, dtype: float64
#
#
# For topic 7 the words with the highest value are:
# ver            2.108782
# pasar          0.143932
# vecino         0.120384
# poder          0.119729
# así            0.110946
# bien           0.101701
# ver ventana    0.100676
# ir ver         0.089421
# niño           0.087925
# ver gente      0.087252
# Name: 7, dtype: float64
#
#
# For topic 8 the words with the highest value are:
# casa           2.159339
# quedar         0.328745
# poder          0.196850
# quedar casa    0.188895
# año            0.120430
# salir casa     0.115563
# sal            0.101762
# llegar         0.090828
# santo          0.089310
# puta           0.089192
# Name: 8, dtype: float64
#
#
# For topic 9 the words with the highest value are:
# hoy          2.160672
# tocar        0.275013
# hoy tocar    0.193458
# hoy salir    0.154503
# aplauso      0.149646
# gracias      0.135492
# mañana       0.132228
# barrio       0.113936
# bonito       0.096914
# sonar        0.096095
# Name: 9, dtype: float64
#
#
# For topic 10 the words with the highest value are:
# ir          2.256090
# ir salir    0.289808
# decir       0.231629
# ir tirar    0.144543
# ir poner    0.118510
# ir ver      0.118138
# pasar       0.106805
# ir hacer    0.095441
# mañana      0.091902
# bien        0.091166
# Name: 10, dtype: float64
#
#
# For topic 11 the words with the highest value are:
# dar          1.832335
# sol          0.537003
# tomar        0.220750
# vida         0.198852
# poder        0.177201
# tomar sol    0.172707
# dar sol      0.164406
# ahora        0.160676
# tener        0.155004
# gracia       0.116951
# Name: 11, dtype: float64
#
#
# For topic 12 the words with the highest value are:
# españa            1.104305
# ventana           1.082345
# bandera           0.755989
# bandera españa    0.433472
# negro             0.409180
# crespón           0.383126
# crespón negro     0.368190
# fallecido         0.289191
# señal             0.274940
# himno             0.266833
# Name: 12, dtype: float64
#
#
# For topic 13 the words with the highest value are:
# foto                   0.825861
# acabar                 0.702087
# segoviano              0.653022
# periódico digital      0.640730
# segoviano periódico    0.640730
# periódico              0.639728
# digital                0.622128
# publicar foto          0.598555
# publicar               0.592584
# acabar publicar        0.588341
# Name: 13, dtype: float64
#
#
# For topic 14 the words with the highest value are:
# gente          1.393753
# policía        0.865916
# calle          0.784768
# mismo          0.157337
# decir          0.155563
# ahora          0.153271
# creer          0.142453
# esperar        0.136855
# gente salir    0.133447
# pasar          0.126663
# Name: 14, dtype: float64

# %%
# column names
topicnames = ['Topic_' + str(i) for i in range(model.n_components)]

# index names
tweets = ['tweet_' + str(i) for i in range(len(texts))]

# %%
# create a dataframe
df_tweet_topic = pd.DataFrame(np.round(nmf_output, 3), columns=topicnames)

# dominant topic
df_tweet_topic['dominant_topic'] = np.argmax(df_tweet_topic.values, axis=1)
df_tweet_topic.head()
# Out:
#    Topic_0  Topic_1  Topic_2  Topic_3  Topic_4  Topic_5  Topic_6  Topic_7  \
# 0    0.001    0.000      0.0    0.000    0.000    0.099    0.044    0.015
# 1    0.000    0.021      0.0    0.000    0.000    0.035    0.000    0.138
# 2    0.002    0.000      0.0    0.071    0.003    0.004    0.002    0.018
# 3    0.002    0.008      0.0    0.000    0.008    0.004    0.001    0.036
# 4    0.003    0.004      0.0    0.006    0.005    0.004    0.008    0.015
#
#    Topic_8  Topic_9  dominant_topic
# 0    0.000    0.000               5
# 1    0.000    0.000               7
# 2    0.009    0.001               3
# 3    0.001    0.001               7
# 4    0.003    0.005               7
